# %%
import matplotlib.pyplot as plt
import matplotlib

import pandas as pd
import numpy as np
from typing import List
from typing import Union
from typing import Iterator
from typing import Optional
import re
import numpy as np
from functools import reduce
import ast
import json
from random import Random

import onnx
import tvm
from tvm.relay.frontend import onnx as ox
from tvm import relay
from tvm.autotvm.graph_tuner.utils import expr2graph

import torch
from torch.utils.data import DataLoader, Dataset, Sampler
from torch import nn
from torch.optim.lr_scheduler import _LRScheduler
from torch.optim import Adam, Optimizer
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset


op_names = [
"torch.Linear", "core.Reshape", "core.ReplicatePad ", "core.ReLU", 
"core.ExpandLast1", "core.Sub", "core.NCHWConv2d", "core.Tril", "core.Mul", 
"core.Clip", "core.Atan", "core.Squeeze", "core.ReduceMax", "core.Or", 
"core.NearestInterp", "core.ExpandLast4", "core.Conv1d", "core.Min", 
"None", "core.Max", "Concat ", "core.Transpose", "core.Round", "core.ArgMax", 
"core.Where", "core.GELU", "core.AvgPool2d", "core.Ceil", "core.BatchNorm2d", 
"Constant", "core.LeakyReLU", "core.Sigmoid", "core.ReduceMean", "core.Add", 
"core.Neg", "core.Triu", "core.TrilinearInterp", "core.Floor", "core.ArgMin", 
"core.Div", "core.Xor", "core.Slice ", "core.BilinearInterp", "core.LinearInterp", 
"core.Abs", "core.Equal", "core.ConstPad ", "torch.Flatten", "core.And", "Input", 
"Cast ", "torch.TorchReduceSum", "core.Cos", "core.ExpandLast2", "core.Softmax", 
"core.Sin", "core.MaxPool2d", "core.BicubicInterp", "core.Less", "core.PReLU", 
"core.ExpandLast3", "core.ReduceMin", "core.ReflectPad ", "core.Tan", "core.Greater",
"torch.PTMatMul"
]


data_type_names = [
    "i64", "i32", "b", "i8", "f64", "i16", "Unknow", "f32", "f16", "u8"
]

vocab = {op:  idx for idx, op in enumerate(op_names)}
op_vocab = {op: idx for idx, op in enumerate(op_names)}

# Load the dataset from the JSON file
json_filename = 'train_1000_1000.json'
with open(json_filename, 'r') as jsonfile:
    loaded_dataset_dicts = json.load(jsonfile)


# Extract the lists from the loaded dataset
node_info_set = [item['node_info'] for item in loaded_dataset_dicts]
edge_info_set = [item['edge_info'] for item in loaded_dataset_dicts]
graph_info_set = [item['graph_info'] for item in loaded_dataset_dicts]
result_set = [item['result'] for item in loaded_dataset_dicts]
count_result = 0
count_true_result = 0
for result in result_set:
    if result == 1:
        count_true_result += 1
    count_result += 1
print("在",count_result,"中有",count_true_result,"个触发bug")

def onek_encoding_unk(value: int, choices: List):
    encoding = [0] * (len(choices) + 1)
    index = choices.index(value) if value in choices else -1
    encoding[index] = 1

    return encoding

def node_features(node_info:list):
    features = onek_encoding_unk(node_info[1], op_names)
    return features

def edge_features(edge_info:list):
    features = []
    for i in range(5):
        features.append(edge_info[2][i])
    tmp_list = onek_encoding_unk(edge_info[3], data_type_names)
    for i in range(len(tmp_list)):
        features.append(tmp_list[i])
    return features

def encode_graph_info(graph_info, op_vocab):
    # 对算子进行编码
    ops = graph_info[2]
    op_indices = [op_vocab.get(op, len(op_vocab)) for op in ops]

    # 创建onehot向量
    op_vector = [0] * (len(op_vocab) + 1)
    for idx in op_indices:
        op_vector[idx] = 1

    encoded_gragh_info = graph_info[:2] + op_vector 
    return encoded_gragh_info

def initialize_weights(model:nn.Module)->None:
    for param in model.parameters():
        if param.dim() == 1:
            nn.init.constant_(param, 0)
        else:
            nn.init.xavier_normal_(param)
            
for h in range(len(graph_info_set)):
    encoded_graph_info = encode_graph_info(graph_info_set[h], op_vocab)
    edge_info_hh = []
    for i in range(5):
        edge_info_hh.append(0)
    edge_info = edge_info_set[h]
    for i in range(len(edge_info)):
        for j in range(5):
            edge_info_hh[j] = edge_info[i][2][j] + edge_info_hh[j]
    
    graph_info = []
    for i in range(len(encoded_graph_info)):
        graph_info.append(encoded_graph_info[i])
    for i in range(len(edge_info_hh)):
        graph_info.append(edge_info_hh[i])
    graph_info_set[h] = graph_info
# Out:
# 在 2000 中有 1000 个触发bug

# %%
len(graph_info_set[1])
# Out:
# 74

# %%
random = Random()
sizes = [0.8, 0.1, 0.1]

indices = list(range(len(graph_info_set)))
random.shuffle(indices)

train_size = int(sizes[0] * len(graph_info_set))
train_val_size = int((sizes[0] + sizes[1]) * len(graph_info_set))

train_data = [graph_info_set[i] for i in indices[:train_size]]
val_data = [graph_info_set[i] for i in indices[train_size:train_val_size]]
test_data = [graph_info_set[i] for i in indices[train_val_size:]]

train_result = [result_set[i] for i in indices[:train_size]]
val_result = [result_set[i] for i in indices[train_size:train_val_size]]
test_result = [result_set[i] for i in indices[train_val_size:]]

train_data_tensor = torch.FloatTensor(train_data)
val_data_tensor = torch.FloatTensor(val_data)
test_data_tensor = torch.FloatTensor(test_data)

train_result_tensor = torch.LongTensor(train_result)
val_result_tensor = torch.LongTensor(val_result)
test_result_tensor = torch.LongTensor(test_result)

train_dataset = TensorDataset(train_data_tensor, train_result_tensor)
val_dataset = TensorDataset(val_data_tensor, val_result_tensor)
test_dataset = TensorDataset(test_data_tensor, test_result_tensor)

# 创建 DataLoader
batch_size = 64  # 可以根据需要调整批次大小
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_data_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_data_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
from hmac import new


new_json_filename = './ort-v1.17.0-testdata_0_6/demo_test_data_info_0.json'
with open(new_json_filename, 'r') as val_jsonfile:
    val_loaded_dataset_dicts = json.load(val_jsonfile)

new_node_info_set = [item['node_info'] for item in val_loaded_dataset_dicts]
new_edge_info_set = [item['edge_info'] for item in val_loaded_dataset_dicts]
new_graph_info_set = [item['graph_info'] for item in val_loaded_dataset_dicts]
new_result_set = [item['result'] for item in val_loaded_dataset_dicts]

for h in range(len(new_graph_info_set)):
    encoded_graph_info = encode_graph_info(new_graph_info_set[h], op_vocab)
    edge_info_hh = []
    for i in range(5):
        edge_info_hh.append(0)
    edge_info = new_edge_info_set[h]
    for i in range(len(edge_info)):
        for j in range(5):
            edge_info_hh[j] = edge_info[i][2][j] + edge_info_hh[j]
    
    graph_info = []
    for i in range(len(encoded_graph_info)):
        graph_info.append(encoded_graph_info[i])
    for i in range(len(edge_info_hh)):
        graph_info.append(edge_info_hh[i])
    new_graph_info_set[h] = graph_info


new_graph_info_tensor = torch.FloatTensor(new_graph_info_set)
new_result_tensor = torch.LongTensor(new_result_set)


new_dataset = TensorDataset(new_graph_info_tensor, new_result_tensor)


batch_size = 64  # 可以根据需要调整批次大小
new_data_loader = DataLoader(new_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn

class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(74, 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.fc2 = nn.Linear(512, 512)
        self.bn2 = nn.BatchNorm1d(512)
        self.fc3 = nn.Linear(512, 256)
        self.bn3 = nn.BatchNorm1d(256)
        self.fc4 = nn.Linear(256, 1)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.5)
        initialize_weights_let(self)

    def forward(self, x):
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc3(x)
        x = self.bn3(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc4(x)
        return torch.sigmoid(x)  # 添加sigmoid激活函数，输出概率值

def initialize_weights_let(model):
    for m in model.modules():
        if isinstance(m, nn.Linear):
            nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.BatchNorm1d):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)

# %%
def train(model, data_loader, optimizer, criterion, num_epochs=1):
    model.train()  # 设置模型为训练模式
    for epoch in range(1):
        total_loss = 0
        for inputs, labels in data_loader:
            optimizer.zero_grad()  # 清空之前的梯度
            outputs = model(inputs)  # 得到模型的输出
            loss = criterion(outputs.squeeze(1), labels.float())  # 计算损失
            loss.backward()  # 反向传播
            optimizer.step()  # 更新参数
            total_loss += loss.item()

        return total_loss / len(data_loader)

def evaluate(model, data_loader, threshold=0.6):
    model.eval()
    total_loss = 0
    correct_predictions = 0
    correct_predictions_positives = 0
    total_samples = 0
    total_positives = 0
    predicted_positives = 0
    with torch.no_grad():
        for batch in data_loader:
            inputs, targets = batch
            outputs = model(inputs).squeeze(1)  # 确保输出是1D tensor
            targets = targets.float()  # 确保标签是float类型，适用于binary_cross_entropy
            loss = F.binary_cross_entropy(outputs, targets)
            total_loss += loss.item()
            predictions = (outputs >= threshold).long()
            correct_predictions += (predictions == targets.long()).sum().item()
            correct_predictions_positives += ((predictions == 1) & (targets == 1)).sum().item()
            total_samples += targets.size(0)
            total_positives += (targets == 1).sum().item()
            predicted_positives += (predictions == 1).sum().item()

    overall_accuracy = correct_predictions / total_samples * 100 if total_samples > 0 else 0
    positive_accuracy = correct_predictions_positives / total_positives * 100 if total_positives > 0 else 0
    return total_loss / len(data_loader), overall_accuracy, positive_accuracy, total_positives, predicted_positives

# %%
model = SimpleNN()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.BCELoss()  # 二元交叉熵损失
model
# Out:
# SimpleNN(
#   (fc1): Linear(in_features=74, out_features=512, bias=True)
#   (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=512, out_features=256, bias=True)
#   (bn3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
class TrainArgs:
    no_cuda = False
    gpu = 0
    num_workers = 16
    batch_size = 16
    dataset_type = 'classification'
    task_names = []
    num_tasks = 1
    seed = 0
    hidden_size = 400
    bias = False
    depth = 3
    dropout = 0.3
    undirected = False
    aggregation = 'norm'
    aggregation_norm = 200
    cuda = True
    ffn_num_layers = 3
    ffn_hidden_size = 300
    init_lr = 1e-4
    max_lr = 1e-3
    final_lr = 1e-4
    num_lrs = 1
    warmup_epochs = 2.0
    epochs = 100

    @property
    def device(self) -> torch.device:
        """The :code:`torch.device` on which to load and process data and models."""
        if not self.cuda:
            return torch.device('cpu')

        return torch.device('cuda', self.gpu)

    @device.setter
    def device(self, device: torch.device) -> None:
        self.cuda = device.type == 'cuda'
        self.gpu = device.index

    @property
    def cuda(self) -> bool:
        """Whether to use CUDA (i.e., GPUs) or not."""
        return not self.no_cuda and torch.cuda.is_available()

    @cuda.setter
    def cuda(self, cuda: bool) -> None:
        self.no_cuda = not cuda
        
args = TrainArgs()

def main():
    best_val_loss = float('inf')
    best_val_accuracy = 0
    best_model_state = model.state_dict()

    for epoch in range(100):
        train_loss = train(model, train_data_loader, optimizer, criterion, num_epochs=1)
        val_loss, val_accuracy, val_positive_accuracy, total_positives, predicted_positives = evaluate(model, val_data_loader)
        print(f'Epoch {epoch+1}/{args.epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%, '
              f'Positive Accuracy: {val_positive_accuracy:.2f}%, Total Positives: {total_positives}, Predicted Positives: {predicted_positives}')

        # Check if the current model is better than the best model so far
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = model.state_dict()
            # Save the best model state
            torch.save(best_model_state, 'LET_best_model.pth')

    # Load the best model state
    model.load_state_dict(best_model_state)

    # Evaluate on the test set
    test_loss, test_accuracy, test_positive_accuracy, test_total_positives, test_predicted_positives = evaluate(model, test_data_loader)
    print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%, '
          f'Test Positive Accuracy: {test_positive_accuracy:.2f}%, Test Total Positives: {test_total_positives}, Test Predicted Positives: {test_predicted_positives}')

# %%
main()
# Out:
# Epoch 1/100, Train Loss: 0.7947, Val Loss: 0.7795, Val Accuracy: 48.00%, Positive Accuracy: 0.00%, Total Positives: 104, Predicted Positives: 0
# Epoch 2/100, Train Loss: 0.8501, Val Loss: 0.6497, Val Accuracy: 50.00%, Positive Accuracy: 4.81%, Total Positives: 104, Predicted Positives: 6
# Epoch 3/100, Train Loss: 0.7582, Val Loss: 0.6607, Val Accuracy: 50.00%, Positive Accuracy: 4.81%, Total Positives: 104, Predicted Positives: 6
# Epoch 4/100, Train Loss: 0.7431, Val Loss: 0.6822, Val Accuracy: 48.50%, Positive Accuracy: 0.96%, Total Positives: 104, Predicted Positives: 1
# Epoch 5/100, Train Loss: 0.7468, Val Loss: 0.6697, Val Accuracy: 53.00%, Positive Accuracy: 11.54%, Total Positives: 104, Predicted Positives: 14
# Epoch 6/100, Train Loss: 0.7360, Val Loss: 0.6475, Val Accuracy: 55.00%, Positive Accuracy: 14.42%, Total Positives: 104, Predicted Positives: 16
# Epoch 7/100, Train Loss: 0.7415, Val Loss: 0.6812, Val Accuracy: 51.50%, Positive Accuracy: 6.73%, Total Positives: 104, Predicted Positives: 7
# Epoch 8/100, Train Loss: 0.7551, Val Loss: 0.6903, Val Accuracy: 51.00%, Positive Accuracy: 10.58%, Total Positives: 104, Predicted Positives: 16
# Epoch 9/100, Train Loss: 0.7127, Val Loss: 0.6835, Val Accuracy: 52.50%, Positive Accuracy: 13.46%, Total Positives: 104, Predicted Positives: 19
# Epoch 10/100, Train Loss: 0.7008, Val Loss: 0.6770, Val Accuracy: 52.00%, Positive Accuracy: 8.65%, Total Positives: 104, Predicted Positives: 10
# Epoch 11/100, Train Loss: 0.7061, Val Loss: 0.6518, Val Accuracy: 54.50%, Positive Accuracy: 16.35%, Total Positives: 104, Predicted Positives: 21
# Epoch 12/100, Train Loss: 0.7158, Val Loss: 0.6755, Val Accuracy: 52.00%, Positive Accuracy: 10.58%, Total Positives: 104, Predicted Positives: 14
# Epoch 13/100, Train Loss: 0.7093, Val Loss: 0.6730, Val Accuracy: 53.50%, Positive Accuracy: 15.38%, Total Positives: 104, Predicted Positives: 21
# Epoch 14/100, Train Loss: 0.7157, Val Loss: 0.6730, Val Accuracy: 52.00%, Positive Accuracy: 10.58%, Total Positives: 104, Predicted Positives: 14
# Epoch 15/100, Train Loss: 0.7131, Val Loss: 0.6545, Val Accuracy: 54.50%, Positive Accuracy: 14.42%, Total Positives: 104, Predicted Positives: 17
# Epoch 16/100, Train Loss: 0.7101, Val Loss: 0.6614, Val Accuracy: 54.00%, Positive Accuracy: 13.46%, Total Positives: 104, Predicted Positives: 16
# Epoch 17/100, Train Loss: 0.7012, Val Loss: 0.6777, Val Accuracy: 54.00%, Positive Accuracy: 14.42%, Total Positives: 104, Predicted Positives: 18
# Epoch 18/100, Train Loss: 0.7156, Val Loss: 0.6769, Val Accuracy: 52.00%, Positive Accuracy: 15.38%, Total Positives: 104, Predicted Positives: 24
# Epoch 19/100, Train Loss: 0.6980, Val Loss: 0.6553, Val Accuracy: 54.00%, Positive Accuracy: 13.46%, Total Positives: 104, Predicted Positives: 16
# Epoch 20/100, Train Loss: 0.6914, Val Loss: 0.6731, Val Accuracy: 53.00%, Positive Accuracy: 13.46%, Total Positives: 104, Predicted Positives: 18
# Epoch 21/100, Train Loss: 0.7024, Val Loss: 0.6824, Val Accuracy: 53.00%, Positive Accuracy: 13.46%, Total Positives: 104, Predicted Positives: 18
# Epoch 22/100, Train Loss: 0.7077, Val Loss: 0.6768, Val Accuracy: 51.50%, Positive Accuracy: 12.50%, Total Positives: 104, Predicted Positives: 19
# Epoch 23/100, Train Loss: 0.6949, Val Loss: 0.6663, Val Accuracy: 52.50%, Positive Accuracy: 14.42%, Total Positives: 104, Predicted Positives: 21
# Epoch 24/100, Train Loss: 0.6956, Val Loss: 0.6611, Val Accuracy: 52.00%, Positive Accuracy: 18.27%, Total Positives: 104, Predicted Positives: 30
# Epoch 25/100, Train Loss: 0.6941, Val Loss: 0.6803, Val Accuracy: 52.00%, Positive Accuracy: 18.27%, Total Positives: 104, Predicted Positives: 30
# Epoch 26/100, Train Loss: 0.6934, Val Loss: 0.6754, Val Accuracy: 53.50%, Positive Accuracy: 15.38%, Total Positives: 104, Predicted Positives: 21
# Epoch 27/100, Train Loss: 0.6885, Val Loss: 0.6668, Val Accuracy: 53.50%, Positive Accuracy: 23.08%, Total Positives: 104, Predicted Positives: 37
# Epoch 28/100, Train Loss: 0.6835, Val Loss: 0.7004, Val Accuracy: 49.50%, Positive Accuracy: 14.42%, Total Positives: 104, Predicted Positives: 27
# Epoch 29/100, Train Loss: 0.6903, Val Loss: 0.6811, Val Accuracy: 51.00%, Positive Accuracy: 10.58%, Total Positives: 104, Predicted Positives: 16
# Epoch 30/100, Train Loss: 0.6937, Val Loss: 0.6859, Val Accuracy: 54.00%, Positive Accuracy: 18.27%, Total Positives: 104, Predicted Positives: 26
# Epoch 31/100, Train Loss: 0.6820, Val Loss: 0.6852, Val Accuracy: 51.50%, Positive Accuracy: 9.62%, Total Positives: 104, Predicted Positives: 13
# Epoch 32/100, Train Loss: 0.6893, Val Loss: 0.6702, Val Accuracy: 54.50%, Positive Accuracy: 20.19%, Total Positives: 104, Predicted Positives: 29
# Epoch 33/100, Train Loss: 0.6838, Val Loss: 0.6671, Val Accuracy: 54.50%, Positive Accuracy: 18.27%, Total Positives: 104, Predicted Positives: 25
# Epoch 34/100, Train Loss: 0.6798, Val Loss: 0.6708, Val Accuracy: 55.00%, Positive Accuracy: 19.23%, Total Positives: 104, Predicted Positives: 26
# Epoch 35/100, Train Loss: 0.6812, Val Loss: 0.6628, Val Accuracy: 55.50%, Positive Accuracy: 26.92%, Total Positives: 104, Predicted Positives: 41
# Epoch 36/100, Train Loss: 0.6757, Val Loss: 0.7033, Val Accuracy: 56.00%, Positive Accuracy: 35.58%, Total Positives: 104, Predicted Positives: 58
# Epoch 37/100, Train Loss: 0.6792, Val Loss: 0.6528, Val Accuracy: 55.50%, Positive Accuracy: 32.69%, Total Positives: 104, Predicted Positives: 53
# Epoch 38/100, Train Loss: 0.6849, Val Loss: 0.6588, Val Accuracy: 56.50%, Positive Accuracy: 35.58%, Total Positives: 104, Predicted Positives: 57
# Epoch 39/100, Train Loss: 0.6774, Val Loss: 0.6789, Val Accuracy: 56.50%, Positive Accuracy: 36.54%, Total Positives: 104, Predicted Positives: 59
# Epoch 40/100, Train Loss: 0.6706, Val Loss: 0.6618, Val Accuracy: 57.00%, Positive Accuracy: 35.58%, Total Positives: 104, Predicted Positives: 56
# Epoch 41/100, Train Loss: 0.6786, Val Loss: 0.6884, Val Accuracy: 54.00%, Positive Accuracy: 20.19%, Total Positives: 104, Predicted Positives: 30
# Epoch 42/100, Train Loss: 0.6811, Val Loss: 0.6631, Val Accuracy: 52.00%, Positive Accuracy: 15.38%, Total Positives: 104, Predicted Positives: 24
# Epoch 43/100, Train Loss: 0.6784, Val Loss: 0.6723, Val Accuracy: 56.50%, Positive Accuracy: 30.77%, Total Positives: 104, Predicted Positives: 47
# Epoch 44/100, Train Loss: 0.6855, Val Loss: 0.6783, Val Accuracy: 54.00%, Positive Accuracy: 34.62%, Total Positives: 104, Predicted Positives: 60
# Epoch 45/100, Train Loss: 0.6730, Val Loss: 0.6619, Val Accuracy: 55.00%, Positive Accuracy: 27.88%, Total Positives: 104, Predicted Positives: 44
# Epoch 46/100, Train Loss: 0.6764, Val Loss: 0.6737, Val Accuracy: 55.50%, Positive Accuracy: 33.65%, Total Positives: 104, Predicted Positives: 55
# Epoch 47/100, Train Loss: 0.6707, Val Loss: 0.6585, Val Accuracy: 55.00%, Positive Accuracy: 27.88%, Total Positives: 104, Predicted Positives: 44
# Epoch 48/100, Train Loss: 0.6782, Val Loss: 0.6606, Val Accuracy: 54.50%, Positive Accuracy: 25.96%, Total Positives: 104, Predicted Positives: 41
# Epoch 49/100, Train Loss: 0.6773, Val Loss: 0.6662, Val Accuracy: 56.00%, Positive Accuracy: 35.58%, Total Positives: 104, Predicted Positives: 58
# Epoch 50/100, Train Loss: 0.6754, Val Loss: 0.7060, Val Accuracy: 54.50%, Positive Accuracy: 35.58%, Total Positives: 104, Predicted Positives: 61
# Epoch 51/100, Train Loss: 0.6727, Val Loss: 0.6789, Val Accuracy: 55.00%, Positive Accuracy: 36.54%, Total Positives: 104, Predicted Positives: 62
# Epoch 52/100, Train Loss: 0.6707, Val Loss: 0.6753, Val Accuracy: 55.50%, Positive Accuracy: 32.69%, Total Positives: 104, Predicted Positives: 53
# Epoch 53/100, Train Loss: 0.6680, Val Loss: 0.6534, Val Accuracy: 56.00%, Positive Accuracy: 34.62%, Total Positives: 104, Predicted Positives: 56
# Epoch 54/100, Train Loss: 0.6663, Val Loss: 0.6819, Val Accuracy: 57.00%, Positive Accuracy: 30.77%, Total Positives: 104, Predicted Positives: 46
# Epoch 55/100, Train Loss: 0.6684, Val Loss: 0.6649, Val Accuracy: 57.00%, Positive Accuracy: 36.54%, Total Positives: 104, Predicted Positives: 58
# Epoch 56/100, Train Loss: 0.6747, Val Loss: 0.6638, Val Accuracy: 57.50%, Positive Accuracy: 28.85%, Total Positives: 104, Predicted Positives: 41
# Epoch 57/100, Train Loss: 0.6614, Val Loss: 0.6806, Val Accuracy: 55.00%, Positive Accuracy: 36.54%, Total Positives: 104, Predicted Positives: 62
# Epoch 58/100, Train Loss: 0.6714, Val Loss: 0.6843, Val Accuracy: 58.50%, Positive Accuracy: 32.69%, Total Positives: 104, Predicted Positives: 47
# Epoch 59/100, Train Loss: 0.6653, Val Loss: 0.6874, Val Accuracy: 58.50%, Positive Accuracy: 35.58%, Total Positives: 104, Predicted Positives: 53
# Epoch 60/100, Train Loss: 0.6664, Val Loss: 0.6762, Val Accuracy: 57.50%, Positive Accuracy: 27.88%, Total Positives: 104, Predicted Positives: 39
# Epoch 61/100, Train Loss: 0.6649, Val Loss: 0.6944, Val Accuracy: 59.00%, Positive Accuracy: 40.38%, Total Positives: 104, Predicted Positives: 62
# Epoch 62/100, Train Loss: 0.6655, Val Loss: 0.6979, Val Accuracy: 56.00%, Positive Accuracy: 40.38%, Total Positives: 104, Predicted Positives: 68
# Epoch 63/100, Train Loss: 0.6589, Val Loss: 0.6569, Val Accuracy: 58.00%, Positive Accuracy: 34.62%, Total Positives: 104, Predicted Positives: 52
# Epoch 64/100, Train Loss: 0.6678, Val Loss: 0.6543, Val Accuracy: 58.50%, Positive Accuracy: 30.77%, Total Positives: 104, Predicted Positives: 43
# Epoch 65/100, Train Loss: 0.6665, Val Loss: 0.6931, Val Accuracy: 58.50%, Positive Accuracy: 33.65%, Total Positives: 104, Predicted Positives: 49
# Epoch 66/100, Train Loss: 0.6558, Val Loss: 0.6694, Val Accuracy: 58.00%, Positive Accuracy: 39.42%, Total Positives: 104, Predicted Positives: 62
# Epoch 67/100, Train Loss: 0.6571, Val Loss: 0.6573, Val Accuracy: 55.50%, Positive Accuracy: 38.46%, Total Positives: 104, Predicted Positives: 65
# Epoch 68/100, Train Loss: 0.6508, Val Loss: 0.6767, Val Accuracy: 62.50%, Positive Accuracy: 52.88%, Total Positives: 104, Predicted Positives: 81
# Epoch 69/100, Train Loss: 0.6606, Val Loss: 0.6615, Val Accuracy: 59.50%, Positive Accuracy: 38.46%, Total Positives: 104, Predicted Positives: 57
# Epoch 70/100, Train Loss: 0.6568, Val Loss: 0.7070, Val Accuracy: 57.00%, Positive Accuracy: 38.46%, Total Positives: 104, Predicted Positives: 62
# Epoch 71/100, Train Loss: 0.6559, Val Loss: 0.6715, Val Accuracy: 60.50%, Positive Accuracy: 47.12%, Total Positives: 104, Predicted Positives: 73
# Epoch 72/100, Train Loss: 0.6549, Val Loss: 0.6728, Val Accuracy: 61.50%, Positive Accuracy: 60.58%, Total Positives: 104, Predicted Positives: 99
# Epoch 73/100, Train Loss: 0.6460, Val Loss: 0.6757, Val Accuracy: 57.00%, Positive Accuracy: 37.50%, Total Positives: 104, Predicted Positives: 60
# Epoch 74/100, Train Loss: 0.6545, Val Loss: 0.6548, Val Accuracy: 58.50%, Positive Accuracy: 45.19%, Total Positives: 104, Predicted Positives: 73
# Epoch 75/100, Train Loss: 0.6404, Val Loss: 0.6946, Val Accuracy: 60.00%, Positive Accuracy: 64.42%, Total Positives: 104, Predicted Positives: 110
# Epoch 76/100, Train Loss: 0.6459, Val Loss: 0.6780, Val Accuracy: 60.50%, Positive Accuracy: 45.19%, Total Positives: 104, Predicted Positives: 69
# Epoch 77/100, Train Loss: 0.6444, Val Loss: 0.6675, Val Accuracy: 63.00%, Positive Accuracy: 55.77%, Total Positives: 104, Predicted Positives: 86
# Epoch 78/100, Train Loss: 0.6319, Val Loss: 0.6602, Val Accuracy: 57.50%, Positive Accuracy: 40.38%, Total Positives: 104, Predicted Positives: 65
# Epoch 79/100, Train Loss: 0.6450, Val Loss: 0.6739, Val Accuracy: 64.00%, Positive Accuracy: 56.73%, Total Positives: 104, Predicted Positives: 86
# Epoch 80/100, Train Loss: 0.6455, Val Loss: 0.6692, Val Accuracy: 60.00%, Positive Accuracy: 37.50%, Total Positives: 104, Predicted Positives: 54
# Epoch 81/100, Train Loss: 0.6481, Val Loss: 0.6805, Val Accuracy: 59.00%, Positive Accuracy: 33.65%, Total Positives: 104, Predicted Positives: 48
# Epoch 82/100, Train Loss: 0.6213, Val Loss: 0.6720, Val Accuracy: 58.00%, Positive Accuracy: 33.65%, Total Positives: 104, Predicted Positives: 50
# Epoch 83/100, Train Loss: 0.6165, Val Loss: 0.6637, Val Accuracy: 57.00%, Positive Accuracy: 36.54%, Total Positives: 104, Predicted Positives: 58
# Epoch 84/100, Train Loss: 0.6328, Val Loss: 0.6667, Val Accuracy: 62.00%, Positive Accuracy: 51.92%, Total Positives: 104, Predicted Positives: 80
# Epoch 85/100, Train Loss: 0.6176, Val Loss: 0.6753, Val Accuracy: 61.00%, Positive Accuracy: 54.81%, Total Positives: 104, Predicted Positives: 88
# Epoch 86/100, Train Loss: 0.6189, Val Loss: 0.6855, Val Accuracy: 76.50%, Positive Accuracy: 94.23%, Total Positives: 104, Predicted Positives: 139
# Epoch 87/100, Train Loss: 0.6186, Val Loss: 0.6842, Val Accuracy: 64.00%, Positive Accuracy: 62.50%, Total Positives: 104, Predicted Positives: 98
# Epoch 88/100, Train Loss: 0.6328, Val Loss: 0.6769, Val Accuracy: 63.00%, Positive Accuracy: 56.73%, Total Positives: 104, Predicted Positives: 88
# Epoch 89/100, Train Loss: 0.6194, Val Loss: 0.6651, Val Accuracy: 61.00%, Positive Accuracy: 53.85%, Total Positives: 104, Predicted Positives: 86
# Epoch 90/100, Train Loss: 0.6302, Val Loss: 0.6289, Val Accuracy: 66.00%, Positive Accuracy: 68.27%, Total Positives: 104, Predicted Positives: 106
# Epoch 91/100, Train Loss: 0.6179, Val Loss: 0.6599, Val Accuracy: 67.50%, Positive Accuracy: 57.69%, Total Positives: 104, Predicted Positives: 81
# Epoch 92/100, Train Loss: 0.5971, Val Loss: 0.6380, Val Accuracy: 66.50%, Positive Accuracy: 57.69%, Total Positives: 104, Predicted Positives: 83
# Epoch 93/100, Train Loss: 0.5842, Val Loss: 0.6532, Val Accuracy: 70.00%, Positive Accuracy: 77.88%, Total Positives: 104, Predicted Positives: 118
# Epoch 94/100, Train Loss: 0.5707, Val Loss: 0.6375, Val Accuracy: 78.50%, Positive Accuracy: 84.62%, Total Positives: 104, Predicted Positives: 115
# Epoch 95/100, Train Loss: 0.5916, Val Loss: 0.6626, Val Accuracy: 65.50%, Positive Accuracy: 60.58%, Total Positives: 104, Predicted Positives: 91
# Epoch 96/100, Train Loss: 0.5514, Val Loss: 0.5851, Val Accuracy: 79.00%, Positive Accuracy: 91.35%, Total Positives: 104, Predicted Positives: 128
# Epoch 97/100, Train Loss: 0.5597, Val Loss: 0.5829, Val Accuracy: 80.50%, Positive Accuracy: 89.42%, Total Positives: 104, Predicted Positives: 121
# Epoch 98/100, Train Loss: 0.5596, Val Loss: 0.5959, Val Accuracy: 75.50%, Positive Accuracy: 76.92%, Total Positives: 104, Predicted Positives: 105
# Epoch 99/100, Train Loss: 0.5528, Val Loss: 0.6114, Val Accuracy: 76.00%, Positive Accuracy: 83.65%, Total Positives: 104, Predicted Positives: 118
# Epoch 100/100, Train Loss: 0.5684, Val Loss: 0.6359, Val Accuracy: 71.50%, Positive Accuracy: 67.31%, Total Positives: 104, Predicted Positives: 93
# Test Loss: 0.6820, Test Accuracy: 73.50%, Test Positive Accuracy: 75.26%, Test Total Positives: 97, Test Predicted Positives: 102

# %%
# 评估模型
total_loss, overall_accuracy, positive_accuracy, total_positives, predicted_positives = evaluate(model, new_data_loader, threshold=0.6)
print(f'Test Loss: {total_loss}')
print(f'Overall Accuracy: {overall_accuracy}%')
print(f'Positive Accuracy: {positive_accuracy}%')
print(f'Total Positives: {total_positives}')
print(f'Predicted Positives: {predicted_positives}')
# Out:
# Test Loss: 0.8193242878236606
# Overall Accuracy: 78.424%
# Positive Accuracy: 83.33333333333334%
# Total Positives: 6
# Predicted Positives: 21580

# %%
def predict(model, data_loader):
    """
    预测测试用例触发 bug 的概率，并按照概率值降序排序。

    参数:
        model: 已经训练好的模型。
        data_loader: DataLoader 实例，用于加载测试数据集。

    返回:
        bug_indices: 按照触发 bug 概率降序排序的测试用例索引序列。
    """
    model.eval()
    predictions = []
    with torch.no_grad():
        for batch in data_loader:
            inputs, targets = batch
            output = model(inputs)
            predictions.extend(output.squeeze(1).tolist())

    # 将预测结果和对应的测试用例组合成元组列表
    bug_probabilities = list(enumerate(predictions))

    # 按照触发 bug 概率降序排序
    bug_probabilities.sort(key=lambda x: x[1], reverse=True)

    # 提取排序后的测试用例索引
    bug_indices = [idx for idx, _ in bug_probabilities]

    return bug_indices, predictions

# %%
import json
RO_detect_bug_time_list_total = []
LET_detect_bug_time_list_total = []
for iteration_count in range(1):
    # 预测
    json_filename = './ort-v1.17.0-testdata_0_7/demo_test_data_info_{}.json'.format(iteration_count)
    with open(json_filename, 'r') as jsonfile:
        demo_test_data_info = json.load(jsonfile)
    json_filename = './ort-v1.17.0-testdata_0_7/demo_test_time_info_{}.json'.format(iteration_count)
    with open(json_filename, 'r') as jsonfile:
        demo_test_time_info = json.load(jsonfile)
    new_node_info_set = [item['node_info'] for item in demo_test_data_info]
    new_edge_info_set = [item['edge_info'] for item in demo_test_data_info]
    new_graph_info_set = [item['graph_info'] for item in demo_test_data_info]
    new_result_set = [item['result'] for item in demo_test_data_info]

    for h in range(len(new_graph_info_set)):
        encoded_graph_info = encode_graph_info(new_graph_info_set[h], op_vocab)
        edge_info_hh = []
        for i in range(5):
            edge_info_hh.append(0)
        edge_info = new_edge_info_set[h]
        for i in range(len(edge_info)):
            for j in range(5):
                edge_info_hh[j] = edge_info[i][2][j] + edge_info_hh[j]
        
        graph_info = []
        for i in range(len(encoded_graph_info)):
            graph_info.append(encoded_graph_info[i])
        for i in range(len(edge_info_hh)):
            graph_info.append(edge_info_hh[i])
        new_graph_info_set[h] = graph_info

    new_graph_info_tensor = torch.FloatTensor(new_graph_info_set)
    new_result_tensor = torch.LongTensor(new_result_set)
    new_dataset = TensorDataset(new_graph_info_tensor, new_result_tensor)
    batch_size = 64  # 可以根据需要调整批次大小
    new_data_loader = DataLoader(new_dataset, batch_size=batch_size, shuffle=False)

    new_gen_time_set = [item['tgen']+item['tmat'] for item in demo_test_time_info]
    new_fetch_time_set = [item['tfetch'] for item in demo_test_time_info]
    new_exec_time_set = [item['texec'] for item in demo_test_time_info]
    new_loss, new_accuracy, new_positive_accuracy, new_total_positives, new_predicted_positives = evaluate(model, new_data_loader)
    print(f'Test Loss: {new_loss:.4f}, Test Accuracy: {new_accuracy:.2f}%, '
              f'Test Positive Accuracy: {new_positive_accuracy:.2f}%, Test Total Positives: {new_total_positives}, Test Predicted Positives: {new_predicted_positives}')
    bug_indices, _ = predict(model, new_data_loader)

    # Random Order就是按照demo_test_data_loader中的顺序来运行
    # LET用bug_indices中的顺序运行
    # 从demo_test_time_info中获取运行时间
    
    LET_detect_bug_time_list = []
    RO_detect_bug_time_list = []
    LET_total_exec_time = 0
    RO_total_exec_time = 0

    # LET方法的时间统计
    for i in bug_indices:
        LET_total_exec_time = new_exec_time_set[i] + LET_total_exec_time
        if new_result_set[i] != 0:
            LET_detect_bug_time_list.append(LET_total_exec_time)
    LET_detect_bug_time_list_total.append(LET_detect_bug_time_list)

    # RO方法的时间统计
    for i in range(len(new_exec_time_set)):
        RO_total_exec_time = new_exec_time_set[i] + RO_total_exec_time
        if new_result_set[i] != 0:
            RO_detect_bug_time_list.append(RO_total_exec_time)
    RO_detect_bug_time_list_total.append(RO_detect_bug_time_list)
# Out:
# Test Loss: 0.8212, Test Accuracy: 78.40%, Test Positive Accuracy: 28.57%, Test Total Positives: 7, Test Predicted Positives: 19436

# %%
average_LET_detect_bug_time = []
average_RO_detect_bug_time = []
for i in range(len(LET_detect_bug_time_list)):
    average_LET_detect_bug_time.append(0)
    average_RO_detect_bug_time.append(0)
for i in range(len(LET_detect_bug_time_list)):
    for j in range(len(LET_detect_bug_time_list_total)):
        average_LET_detect_bug_time[i] += LET_detect_bug_time_list_total[j][i]
        average_RO_detect_bug_time[i] += RO_detect_bug_time_list_total[j][i]
for i in range(len(LET_detect_bug_time_list)):
    average_LET_detect_bug_time[i] = average_LET_detect_bug_time[i] / len(LET_detect_bug_time_list_total)
    average_RO_detect_bug_time[i] = average_RO_detect_bug_time[i] / len(LET_detect_bug_time_list_total)


# 创建图表
plt.figure(figsize=(10, 6))

# 绘制 LET_detect_bug_time_list
plt.plot(average_LET_detect_bug_time, label='LET Detect Bug Time', marker='o')

# 绘制 RO_detect_bug_time_list
plt.plot(average_RO_detect_bug_time, label='RO Detect Bug Time', marker='x')

# 添加标题和标签
plt.title('Train: ort-v1.16.0, Pred: ort-v1.17.0')
plt.xlabel('Bug')
plt.ylabel('Bug Detection Time')

# 添加图例
plt.legend()

# 显示图表
plt.grid(True)
plt.show()

# %%
import pickle
with open("let-ort-v1.17.0-testdata_0_7.pkl", 'wb') as file:
    pickle.dump(average_LET_detect_bug_time, file)
